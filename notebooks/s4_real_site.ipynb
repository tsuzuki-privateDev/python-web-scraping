# %% [markdown]
# ## 実際のサイトのHTMLを取得してみる

# %%
import requests
from bs4 import BeautifulSoup
import csv
from pathlib import Path

url = "https://blog.python.org/"
response = requests.get(url, timeout=10)    # 10秒待つ

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, "html.parser")

    items = soup.find_all("h3", class_="post-title")
    results = []

    for item in items:
        title = item.a.text
        url = item.a["href"]
        item_dict = {
            "title": title,
            "url": url
        }
        results.append(item_dict)

    print(results[:3])

    Path("outputs").mkdir(exist_ok=True)

    with open("outputs/python_blog.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["title", "url"])
        writer.writeheader()
        for row in results:
            writer.writerow(row)
# Out:
# [{'title': 'Python 3.14.3 and 3.13.12 are now available!', 'url': 'https://pythoninsider.blogspot.com/2026/02/python-3143-and-31312-are-now-available.html'}, {'title': 'Python 3.15.0 alpha 5 (yes, another alpha!)', 'url': 'https://pythoninsider.blogspot.com/2026/01/python-3150-alpha-5-yes-another-alpha.html'}, {'title': 'Python 3.15.0 alpha 4', 'url': 'https://pythoninsider.blogspot.com/2026/01/python-3150-alpha-4.html'}]
